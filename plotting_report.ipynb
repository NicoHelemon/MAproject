# %%
import pandas as pd
import json
from itertools import product

from utils.static import *
from utils.plots import *
plot = Plot()

# %%
D_p_dists, D_p_edges, M_p_dists, M_p_edges = load_perturbation_dfs()

# %%
D_p_dd = compute_perturbation_distances_deviation(D_p_dists)

# %%
g = 'RG'
w = 'Exp'

for p in P_NAME:
    for m in METRICS:
        plot.perturbation_distances(
            D_p_dists[p], g, w, m, p, y_axis_range=(0, M_p_dists[m.id][(g, w)]), report=True)

# %%
for p in P_NAME:
    for m in METRICS:
        plot.perturbation_deviation_by_graph(
            D_p_dd[p][m.id], m, p, D_p_dd['max'][m.id], report = True)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# ...

# %%
for p in P_NAME:
    for m in METRICS:
        plot.perturbation_deviation_by_graph(D_p_dd[p][m.id], m, p, D_p_dd['max'][m.id])
    plot.perturbation_deviation_by_sparsifier(D_p_dd[p], p)
    plot.perturbation_deviation_by_metric(D_p_dd[p], p)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# ...

# %%
import pandas as pd
import json
from itertools import product

from utils.static import *
from utils.plots import *
plot = Plot()

# %%
D_g_dists, D_g_edges, M_g_dists, M_g_edges = load_gaussian_noise_dfs()

# %%
for g in G_NAME:
    for w in W_NAME:
        for m in METRICS:
            plot.gaussian_noise_distances(D_g_dists, g, w, m, y_axis_range = (0, M_g_dists[m.id]))
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# ...

# %%
for g in G_NAME:
    for w in W_NAME:
        for e_mes in E_MES:
            plot.gaussian_noise_edges(D_g_edges, g, w, e_mes, y_axis_range = (0, M_g_edges[e_mes]))
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# ...

# %%
D_g_dd = compute_gaussian_noise_distances_deviation(D_g_dists)

# %%
for m in METRICS:
    plot.gaussian_noise_deviation_by_graph(D_g_dd[m.id], m)
plot.gaussian_noise_deviation_by_sparsifier(D_g_dd)
plot.gaussian_noise_deviation_by_metric(D_g_dd)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# ...

# %%
import pandas as pd
import json
from itertools import product

from utils.static import *
from utils.plots import *
plot = Plot()

# %%
D_c = {}

for i in range(20):
    D_c[i] = {}
    for s in S_NAME:
        D_c[i][s] = pd.read_csv(f'results/clustering/{i}/{s}.csv')

with open(f'results/clustering/{0}/labels.json', "r") as json_file:
    labels = json.load(json_file)

# %%
_ = compute_mean_aupr(D_c, labels, ['graph', 'weight'])
_ = compute_mean_aupr(D_c, labels, ['graph'])
_ = compute_mean_aupr(D_c, labels, ['weight'])

# %%
with open(f'results/clustering/(Graph, Weight)/mean_aupr.json', "r") as json_file:
    D_a = json.load(json_file)
    plot.clustering_aupr_by_sparsifier(D_a, ['graph', 'weight'])
    plot.clustering_aupr_by_metric(D_a, ['graph', 'weight'])
    print(D_a['best_approx_index'])

with open(f'results/clustering/(Weight)/mean_aupr.json', "r") as json_file:
    D_a = json.load(json_file)
    plot.clustering_aupr_by_sparsifier(D_a, ['weight'])
    plot.clustering_aupr_by_metric(D_a, ['weight'])
    print(D_a['best_approx_index'])

with open(f'results/clustering/(Graph)/mean_aupr.json', "r") as json_file:
    D_a = json.load(json_file)
    plot.clustering_aupr_by_sparsifier(D_a, ['graph'])
    plot.clustering_aupr_by_metric(D_a, ['graph'])
    print(D_a['best_approx_index'])
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# 13
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# 8
# ...

# %%
for metric in METRICS:
    plot.clustering_precision_recall_curve(D_c[13], metric, labels, ['graph', 'weight'])
    plot.clustering_precision_recall_curve(D_c[13], metric, labels, ['graph'])
    plot.clustering_precision_recall_curve(D_c[13], metric, labels, ['weight'])
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# ...

# %%
for metric in METRICS:
    plot.clustering_precision_recall_curve_3D(D_c[13], metric, labels, ['graph', 'weight'])
    plot.clustering_precision_recall_curve_3D(D_c[13], metric, labels, ['graph'])
    plot.clustering_precision_recall_curve_3D(D_c[13], metric, labels, ['weight'])
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# ...

# %%
for metric in METRICS:
    plot.clustering(D_c[13], metric, labels)
# Out:
# 0.3
# 1.3
# dict_values(['red', 'orange', 'yellow'])
# dict_values(['green', 'blue', 'pink', 'violet'])
# c:\Users\Nicol\Miniconda3\lib\site-packages\radialtree.py:431: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# 0.3
# ...
